# %%
import torch

a = torch.randn(100)
b = torch.topk(a, 10).indices
print(b)
# Out:
# tensor([16, 24, 95, 62, 83, 18,  0, 59, 32, 54])

# %%
g = []
g.append(torch.randn((100, 7)))
g.append(torch.randn((100, 7)))
print(torch.stack(g, dim=1).shape)
# Out:
# torch.Size([100, 2, 7])

# %%
e =c.expand(d.shape[0], -1, -1).contiguous()

# %%
e.shape
# Out:
# torch.Size([100, 1, 7])
