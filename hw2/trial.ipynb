# %%
import torch

a = torch.randn(100)
b = torch.topk(a, 10).indices
print(b)
# Out:
# tensor([46, 91, 25, 16, 56, 94, 79, 64, 45, 24])

# %%
c = torch.randn((1,7))

# %%
c.squeeze().shape
# Out:
# torch.Size([7])
